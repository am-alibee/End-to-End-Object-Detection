# %%
print("okay")
# Out:
# okay

# %%
required_list = ["one", "two"]

given_list = ["two", "one", "three"]

# %%
required_list = set(["one", "two", "three"])

given_list = set(["two", "one", "three"])

if required_list != given_list:
    print("fitnah")

# %%
required_list == given_list
# Out:
# True

# %%
import yaml

with open("test.yaml", "r") as f:
    data = yaml.safe_load(f)

print(data)
# Out:
# {'key': 'value', 'mylist': ['item1', 'item2', 'item3'], 'mydict': {'key1': 'value1', 'key2': 'value2'}, 'multi-line-str': 'Hello World\nThis is a\nmulti-line string'}

# %%
import subprocess

# %%
result = subprocess.run(["git", "status"])

print(f"Return code: {result.returncode}")
# Out:
# Return code: 0
